# %% [markdown]
# # I. Classification
# ## 1. k-Nearest Neighbors

# %% [markdown]
# ###Implement kNN classification for the above dataset.

# %%
from sklearn import datasets
import matplotlib.pyplot as plt



#load

digits = datasets.load_digits()

# %%
from sklearn.model_selection import train_test_split
import numpy as np

x = digits.data
y= digits.target

x_train,x_test,y_train, y_test = train_test_split(x,y,test_size = 0.2)

# %% [markdown]
# ###Compute and plot the accuracy scores by k values.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

#For warning message
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5, weights='uniform')

# Scale the features using StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# Initialize the classifier with different k values
k_values = [1, 3, 5, 7, 8]
train_accuracy_scores = []
test_accuracy_scores = []

for k in k_values:
    # Initialize kNN classifier with the current k value
    knn = KNeighborsClassifier(n_neighbors=k)
    # Train the classifier
    knn.fit(x_train, y_train)
    
    # Compute and store the accuracy scores for training and test data
    y_train_pred = knn.predict(x_train)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    train_accuracy_scores.append(train_accuracy)
    
    y_test_pred = knn.predict(x_test)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    test_accuracy_scores.append(test_accuracy)

# Plot the accuracy scores
import matplotlib.pyplot as plt
plt.plot(k_values, train_accuracy_scores, label='Training Accuracy')
plt.plot(k_values, test_accuracy_scores, label='Testing Accuracy')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Accuracy')
plt.title('kNN Classification Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # 2. Support Vector Machine

# %% [markdown]
# ## Implement SVM classifier for MNIST dataset.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# Load the MNIST dataset
mnist = fetch_openml('mnist_784')
X = mnist.data
y = mnist.target

# Randomly select a subset of the data
subset_size = 3000
X_subset, _, y_subset, _ = train_test_split(X, y, train_size=subset_size, random_state=42)

# %%
# Use the subset for training and testing
X_train, X_test, y_train, y_test = train_test_split(X_subset, y_subset, test_size=0.2, random_state=42)

# Scale the features of the dataset
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Create SVM classifiers with different kernels
svm_linear = SVC(kernel='linear', C=1.0)
svm_poly = SVC(kernel='poly', degree=3, C=1.0)
svm_rbf = SVC(kernel='rbf', gamma='auto', C=1.0)

# Train the classifiers on the training data
svm_linear.fit(X_train, y_train)
svm_poly.fit(X_train, y_train)
svm_rbf.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %% [markdown]
# ## Compute and compare the accuracy scores for at least 3 different kernels by using metrics.classification_report

# %%
# Predict the labels of the test data
y_pred_linear = svm_linear.predict(X_test)
y_pred_poly = svm_poly.predict(X_test)
y_pred_rbf = svm_rbf.predict(X_test)

# Print the classification report for each classifier
print("Linear kernel:")
print(classification_report(y_test, y_pred_linear,zero_division=1))
print("Polynomial kernel:")
print(classification_report(y_test, y_pred_poly,zero_division=1))
print("RBF kernel:")
print(classification_report(y_test, y_pred_rbf,zero_division=1))
# Out:
# Linear kernel:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        62
#            1       0.99      0.96      0.97        78
#            2       0.94      0.94      0.94        54
#            3       0.90      0.92      0.91        62
#            4       0.92      0.96      0.94        56
#            5       0.92      0.87      0.89        63
#            6       0.93      0.97      0.95        59
#            7       0.93      0.86      0.89        58
#            8       0.90      0.86      0.88        65
#            9       0.75      0.84      0.79        43
#
#     accuracy                           0.92       600
#    macro avg       0.91      0.92      0.91       600
# weighted avg       0.92      0.92      0.92       600
#
# Polynomial kernel:
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.86        62
#            1       0.96      0.94      0.95        78
# ...

# %% [markdown]
# Linear kernel and RBF kernelperform similarly well, with an accuracy of 0.92, while the polynomial kernel performs significantly worse, with an accuracy of 0.76. So in here Linear and RBF will be better kernel.

# %% [markdown]
# ## 3. Naïve Bayes

# %% [markdown]
# ### Compute the accuracy scores and plot the confusion matrix of the same dataset using
#
# ### Naïve Bayes classifier. Hint: from sklearn.metrics import confusion_matrix

# %%
# Import function
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt


# Train a Naive Bayes classifier on the training data
clf = GaussianNB()
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Compute the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy score: ", accuracy)

# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", cbar=False)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.show()
# Out:
# Accuracy score:  0.5933333333333334

# %% [markdown]
# ### Compare the accuracy of different classifiers in the same plot

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

#remove furture warming
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from scipy import stats

# Set keepdims to True explicitly
mode, _ = stats.mode(_y[neigh_ind, k], axis=1, keepdims=True)

# Initialize the classifiers
knn = KNeighborsClassifier(n_neighbors=5)
bayes = GaussianNB()
svm = SVC(kernel='linear', C=1.0)

# Train the classifiers
knn.fit(X_train, y_train)
bayes.fit(X_train, y_train)
svm.fit(X_train, y_train)

# Predict the classes using the trained classifiers
y_pred_knn = knn.predict(X_test)
y_pred_bayes = bayes.predict(X_test)
y_pred_svm = svm.predict(X_test)

# Compute the accuracy scores
acc_knn = accuracy_score(y_test, y_pred_knn)
acc_bayes = accuracy_score(y_test, y_pred_bayes)
acc_svm = accuracy_score(y_test, y_pred_svm)

# Compute the confusion matrices
cm_knn = confusion_matrix(y_test, y_pred_knn)
cm_bayes = confusion_matrix(y_test, y_pred_bayes)
cm_svm = confusion_matrix(y_test, y_pred_svm)

# Plot the accuracy scores
labels = ['Bayes','KNN',  'SVM']
accuracy_scores = [acc_bayes,acc_knn,  acc_svm]
plt.bar(labels, accuracy_scores)
plt.title('Accuracy scores of different classifiers')
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # II. Regression

# %% [markdown]
# ## 1. Linear Regression

# %% [markdown]
# ### Use seaborn to visualize the data of Gapminder like following image:

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
gapminder_df = pd.read_csv('gapminder.csv')

# Compute the correlation matrix
corr_matrix = gapminder_df.corr()

# Create the heatmap
sns.heatmap(corr_matrix, cmap='YlGnBu', annot=False)#base on the example, remove number texts on the map

# Show the plot
plt.show()

# %% [markdown]
# ### Apply linear regression with the 'fertility' feature to predict life expectancy.

# %%
from sklearn.linear_model import LinearRegression

# Load the data
gapminder_df = pd.read_csv('gapminder.csv')

# Select the 'fertility' and 'life_expectancy' columns
X = gapminder_df[['fertility']]
y = gapminder_df['life']

# Split the data into training and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate the mean squared error on the test set
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print('Mean squared error:', mse)

# Plot the linear regression line
plt.scatter(X_test, y_test, color='blue')
plt.plot(X_test, y_pred, color='red')
plt.title('Linear Regression: Fertility vs Life Expectancy')
plt.xlabel('Fertility')
plt.ylabel('Life Expectancy')
plt.show()
# Out:
# Mean squared error: 22.301733268079392

# %% [markdown]
# ### Apply linear regression with the all features to predict life expectancy. Compare the
#
# ### model score when using all features to one feature in previous step.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load the data
gapminder_df = pd.read_csv('gapminder.csv')

# Convert the 'region' column to a set of binary columns
gapminder_df = pd.get_dummies(gapminder_df, columns=['Region'])

# Select the input and output variables
X = gapminder_df.drop(['life'], axis=1)
y = gapminder_df['life']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit the linear regression model
model_all = LinearRegression()
model_all.fit(X_train, y_train)

# Make predictions on the test set
y_pred_all = model_all.predict(X_test)

# Calculate the mean squared error on the test set
mse_all = mean_squared_error(y_test, y_pred_all)
print('Mean squared error:', mse_all)
# Out:
# Mean squared error: 16.7884936234452

# %% [markdown]
# #### Answer: MSE as the model score. Under the MSE, all features' score is usally lower than singal features. Because of that Lower values of MSE indicate a better fit to the data, all features' prediction is better.

# %% [markdown]
# ### Apply 5-fold cross-validation (for both 2 above steps) and compare your model score
# ### accuracy. Hint: from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### Singal feature

# %%
from sklearn.model_selection import cross_val_score

# Load the data since the previous datasets has been changed so reload
gapminder_df = pd.read_csv('gapminder.csv')

# Split the data into input and output variables
X = gapminder_df[['fertility']]
y = gapminder_df['life']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit the linear regression model
model_one = LinearRegression()
model_one.fit(X_train, y_train)

# Calculate the R-squared score using 5-fold cross-validation
scores_one = cross_val_score(model_one, X, y, cv=5, scoring='r2')
print('R-squared scores (one feature):', scores_one)
# Out:
# R-squared scores (one feature): [0.71001079 0.75007717 0.55271526 0.547501   0.52410561]

# %% [markdown]
# #### all features

# %%
# Convert the 'region' column to a set of binary columns
gapminder_df = pd.get_dummies(gapminder_df, columns=['Region'])

# Select the input and output variables
X = gapminder_df.drop(['life'], axis=1)
y = gapminder_df['life']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Fit the linear regression model
model_all = LinearRegression()
model_all.fit(X_train, y_train)

# Calculate the R-squared score using 5-fold cross-validation
scores_all = cross_val_score(model_all, X, y, cv=5, scoring='r2')
print('R-squared scores (all features):', scores_all)
# Out:
# R-squared scores (all features): [0.8196741  0.80301541 0.89758712 0.80425614 0.94015848]

# %% [markdown]
# #### Answer:Since the R-squared score measures how well the regression line fits the data points. The higher the R-squared value, the better the regression line fits the data and the stronger the relationship between the independent variables and the dependent variable and R-squared scores (all features) has higher score than the single feature, so that R-squared scores (all features) can predict the things better.

# %% [markdown]
# ## 2. Logistic Regression

# %% [markdown]
# ### We will be detecting credit card fraud based on the different features of our dataset with
# ### Logistic Regression

# %% [markdown]
# ### Load the ‘creditcard.csv’ file into dataframe. The attribute ‘Class’ is marked for fraud transactions (Class = 1).

# %%
# Load the data
df = pd.read_csv('creditcard.csv')

frauds = df.loc[df['Class']] == 1
non_frauds = df.loc[df['Class'] == 0]
print(len(frauds), "frauds,", len(non_frauds), "nonfrauds.")
# Out:
# 284807 frauds, 284315 nonfrauds.

# %% [markdown]
# ### Compare the relation between Class and Amount. Conclusion?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('creditcard.csv')

fig, ax = plt.subplots()
fig.set_size_inches(10, 6)

sns.regplot(x='Amount', y='Class', data=df[df.Class == 1], ci=None, color='darkorange',logistic=True, fit_reg=False)
sns.regplot(x='Amount', y='Class', data=df[df.Class == 0], ci=None, color='royalblue', logistic=True,fit_reg=False)

ax.set_xlim([0, df.Amount.max()])
ax.set_ylim([0, 1])

plt.legend(loc='upper right', labels=['frauds','nonfrauds'])
plt.show()

# %% [markdown]
# #### Answer: Form this plot, two facts can be show. The first is less amount easier become frauds. Second is that frauds much less than nonfrauds.

# %% [markdown]
# ## Use Logistic Regression to predict the fraud transactions and plot the confusion matrix of the model.

# %%
from sklearn.linear_model import LogisticRegression

# Load the data
df = pd.read_csv('creditcard.csv')

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class', axis=1), df['Class'], test_size=0.2, random_state=42)

# Scale the data solve th problem of "specified maximum number of iterations"
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Fit a logistic regression model
lr = LogisticRegression()
lr.fit(X_train_scaled, y_train)

# Predict on the test set
X_test_scaled = scaler.transform(X_test)
y_pred = lr.predict(X_test_scaled)

# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion matrix of Logistic Regression')
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.show()
